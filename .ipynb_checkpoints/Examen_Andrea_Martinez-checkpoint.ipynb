# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_csv("amazon.csv")

# %%
a
# Out:
#                                                   Name              Author  \
# 0                        10-Day Green Smoothie Cleanse            JJ Smith
# 1                                    11/22/63: A Novel        Stephen King
# 2              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 3                                                 1984       George Orwell
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 645       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 646  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 647  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 648  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 649  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#      User Rating  Reviews   Price  Price_r  Year        Genre
# ...

# %%
atemp = a.loc[ : , ['Author','Year','Price']]

# %%
atemp
# Out:
#                  Author  Year   Price
# 0              JJ Smith  2016   $8.00
# 1          Stephen King  2011  $22.00
# 2    Jordan B. Peterson  2018  $15.00
# 3         George Orwell  2021   $7.48
# 4         George Orwell  2017   $6.00
# ..                  ...   ...     ...
# 645         Jeff Kinney  2019   $8.00
# 646         Jen Sincero  2016   $8.00
# 647         Jen Sincero  2017   $8.00
# 648         Jen Sincero  2018   $8.00
# 649         Jen Sincero  2019   $8.00
#
# [650 rows x 3 columns]

# %%
 atemp.groupby( ["Author","Year"] , as_index = False ).agg( { "Price" : ["count"] } )
# Out:
#                  Author  Year Price
#                               count
# 0      Abraham Verghese  2010     1
# 1      Abraham Verghese  2011     1
# 2        Adam Gasiewski  2017     1
# 3         Adam Mansbach  2011     1
# 4          Adam Silvera  2021     1
# ..                  ...   ...   ...
# 584  Wonder House Books  2021     1
# 585  Workman Publishing  2020     2
# 586  Workman Publishing  2021     1
# 587        Zhi Gang Sha  2009     1
# 588        Zhi Gang Sha  2013     1
#
# [589 rows x 3 columns]

# %%
atemp.columns = atemp.columns.droplevel(2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [116], in <cell line: 1>()
# ----> 1 atemp.columns = atemp.columns.droplevel(2)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2061, in Index.droplevel(self, level)
#    2058 if not isinstance(level, (tuple, list)):
#    2059     level = [level]
# -> 2061 levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    2063 return self._drop_level_numbers(levnums)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2061, in <genexpr>(.0)
#    2058 if not isinstance(level, (tuple, list)):
#    2059     level = [level]
# -> 2061 levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    2063 return self._drop_level_numbers(levnums)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:1936, in Index._get_level_number(self, level)
# ...

# %%
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_120\888763100.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   x_group.colunms = x_group.columns.droplevel(1)

# %%
#Ejercicio 2

# %%
btemp = a.loc[ : , ['Name','Author','Year']]

# %%
btemp
# Out:
#                                                   Name              Author  \
# 0                        10-Day Green Smoothie Cleanse            JJ Smith
# 1                                    11/22/63: A Novel        Stephen King
# 2              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 3                                                 1984       George Orwell
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 645       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 646  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 647  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 648  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 649  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#      Year
# 0    2016
# 1    2011
# 2    2018
# 3    2021
# ...

# %%
x_group = btemp.groupby( ["Author","Year"] , as_index = False ).agg( { "Name" : ["count"] } )

# %%
x_group
# Out:
#                  Author  Year  Name
#                               count
# 0      Abraham Verghese  2010     1
# 1      Abraham Verghese  2011     1
# 2        Adam Gasiewski  2017     1
# 3         Adam Mansbach  2011     1
# 4          Adam Silvera  2021     1
# ..                  ...   ...   ...
# 584  Wonder House Books  2021     1
# 585  Workman Publishing  2020     2
# 586  Workman Publishing  2021     1
# 587        Zhi Gang Sha  2009     1
# 588        Zhi Gang Sha  2013     1
#
# [589 rows x 3 columns]

# %%
x_group.columns = x_group.columns.droplevel(1)

# %%
x_group
# Out:
#                  Author  Year  Name
# 0      Abraham Verghese  2010     1
# 1      Abraham Verghese  2011     1
# 2        Adam Gasiewski  2017     1
# 3         Adam Mansbach  2011     1
# 4          Adam Silvera  2021     1
# ..                  ...   ...   ...
# 584  Wonder House Books  2021     1
# 585  Workman Publishing  2020     2
# 586  Workman Publishing  2021     1
# 587        Zhi Gang Sha  2009     1
# 588        Zhi Gang Sha  2013     1
#
# [589 rows x 3 columns]

# %%
#Ejercicio 3

# %%
a
# Out:
#                                                   Name              Author  \
# 0                        10-Day Green Smoothie Cleanse            JJ Smith
# 1                                    11/22/63: A Novel        Stephen King
# 2              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 3                                                 1984       George Orwell
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 645       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 646  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 647  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 648  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 649  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#      User Rating  Reviews   Price  Price_r  Year        Genre
# ...

# %%
ctemp = a.loc[ : , ['Year','Genre','User Rating']]

# %%
ctemp
# Out:
#      Year        Genre  User Rating
# 0    2016  Non Fiction          4.7
# 1    2011      Fiction          4.6
# 2    2018  Non Fiction          4.7
# 3    2021      Fiction          4.7
# 4    2017      Fiction          4.7
# ..    ...          ...          ...
# 645  2019      Fiction          4.9
# 646  2016  Non Fiction          4.7
# 647  2017  Non Fiction          4.7
# 648  2018  Non Fiction          4.7
# 649  2019  Non Fiction          4.7
#
# [650 rows x 3 columns]

# %%
z_group = ctemp.groupby( ["Year", "Genre"] , as_index = False ).agg( { "User Rating" : ["mean"] } )

# %%
z_group
# Out:
#     Year        Genre User Rating
#                              mean
# 0   2009      Fiction    4.591667
# 1   2009  Non Fiction    4.576923
# 2   2010      Fiction    4.615000
# 3   2010  Non Fiction    4.520000
# 4   2011      Fiction    4.619048
# 5   2011  Non Fiction    4.513793
# 6   2012      Fiction    4.495238
# 7   2012  Non Fiction    4.558621
# 8   2013      Fiction    4.545833
# 9   2013  Non Fiction    4.561538
# 10  2014      Fiction    4.631034
# 11  2014  Non Fiction    4.609524
# 12  2015      Fiction    4.652941
# 13  2015  Non Fiction    4.645455
# 14  2016      Fiction    4.715789
# 15  2016  Non Fiction    4.654839
# 16  2017      Fiction    4.737500
# 17  2017  Non Fiction    4.588462
# 18  2018      Fiction    4.738095
# 19  2018  Non Fiction    4.617241
# 20  2019      Fiction    4.820000
# 21  2019  Non Fiction    4.686667
# 22  2020      Fiction    4.713043
# 23  2020  Non Fiction    4.737037
# 24  2021      Fiction    4.716667
# ...

# %%
z_group.columns = z_group.columns.droplevel(1)

# %%
z_group
# Out:
#     Year        Genre  User Rating
# 0   2009      Fiction     4.591667
# 1   2009  Non Fiction     4.576923
# 2   2010      Fiction     4.615000
# 3   2010  Non Fiction     4.520000
# 4   2011      Fiction     4.619048
# 5   2011  Non Fiction     4.513793
# 6   2012      Fiction     4.495238
# 7   2012  Non Fiction     4.558621
# 8   2013      Fiction     4.545833
# 9   2013  Non Fiction     4.561538
# 10  2014      Fiction     4.631034
# 11  2014  Non Fiction     4.609524
# 12  2015      Fiction     4.652941
# 13  2015  Non Fiction     4.645455
# 14  2016      Fiction     4.715789
# 15  2016  Non Fiction     4.654839
# 16  2017      Fiction     4.737500
# 17  2017  Non Fiction     4.588462
# 18  2018      Fiction     4.738095
# 19  2018  Non Fiction     4.617241
# 20  2019      Fiction     4.820000
# 21  2019  Non Fiction     4.686667
# 22  2020      Fiction     4.713043
# 23  2020  Non Fiction     4.737037
# 24  2021      Fiction     4.716667
# 25  2021  Non Fiction     4.746154

# %%
z_group.loc[ : , ['Year','Genre','User Rating']].drop_duplicates()
# Out:
#      Year        Genre  User Rating
# 0    2016  Non Fiction          4.7
# 1    2011      Fiction          4.6
# 2    2018  Non Fiction          4.7
# 3    2021      Fiction          4.7
# 4    2017      Fiction          4.7
# ..    ...          ...          ...
# 608  2010  Non Fiction          4.8
# 609  2011  Non Fiction          4.8
# 613  2009      Fiction          4.3
# 614  2019  Non Fiction          4.9
# 619  2020      Fiction          4.0
#
# [187 rows x 3 columns]

# %%
z_group.describe()
# Out:
#               Year  User Rating
# count   187.000000   187.000000
# mean   2014.454545     4.505348
# std       3.562320     0.301383
# min    2009.000000     3.300000
# 25%    2012.000000     4.300000
# 50%    2014.000000     4.600000
# 75%    2017.000000     4.700000
# max    2021.000000     4.900000

# %%
#Ejercicio 4

# %%
a
# Out:
#                                                   Name              Author  \
# 0                        10-Day Green Smoothie Cleanse            JJ Smith
# 1                                    11/22/63: A Novel        Stephen King
# 2              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 3                                                 1984       George Orwell
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 645       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 646  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 647  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 648  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 649  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#      User Rating  Reviews   Price  Price_r  Year        Genre
# ...

# %%
dtemp = a.loc[ : , ['Author','Year','User Rating']]

# %%
dtemp
# Out:
#                  Author  Year  User Rating
# 0              JJ Smith  2016          4.7
# 1          Stephen King  2011          4.6
# 2    Jordan B. Peterson  2018          4.7
# 3         George Orwell  2021          4.7
# 4         George Orwell  2017          4.7
# ..                  ...   ...          ...
# 645         Jeff Kinney  2019          4.9
# 646         Jen Sincero  2016          4.7
# 647         Jen Sincero  2017          4.7
# 648         Jen Sincero  2018          4.7
# 649         Jen Sincero  2019          4.7
#
# [650 rows x 3 columns]

# %%
y_group = dtemp.groupby( ["Author", "Year"] , as_index = False ).agg( { "User Rating" : ["count","median"] } )

# %%
y_group
# Out:
#                  Author  Year User Rating
#                                     count median
# 0      Abraham Verghese  2010           1    4.6
# 1      Abraham Verghese  2011           1    4.6
# 2        Adam Gasiewski  2017           1    4.4
# 3         Adam Mansbach  2011           1    4.8
# 4          Adam Silvera  2021           1    4.6
# ..                  ...   ...         ...    ...
# 584  Wonder House Books  2021           1    4.6
# 585  Workman Publishing  2020           2    4.8
# 586  Workman Publishing  2021           1    4.8
# 587        Zhi Gang Sha  2009           1    4.6
# 588        Zhi Gang Sha  2013           1    4.6
#
# [589 rows x 4 columns]

# %%
y_group.describe()
# Out:
#               Year User Rating
#                          count      median
# count   589.000000  589.000000  589.000000
# mean   2015.181664    1.103565    4.635059
# std       3.720133    0.441631    0.218095
# min    2009.000000    1.000000    3.300000
# 25%    2012.000000    1.000000    4.500000
# 50%    2015.000000    1.000000    4.700000
# 75%    2018.000000    1.000000    4.800000
# max    2021.000000    6.000000    4.900000

# %%
y_group.loc[ : , ['Author', '2009',]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [191], in <cell line: 1>()
# ----> 1 y_group.loc[ : , ['Author', '2009',]]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1140, in _LocIndexer._getitem_tuple(self, tup)
#    1138 with suppress(IndexingError):
#    1139     tup = self._expand_ellipsis(tup)
# -> 1140     return self._getitem_lowerdim(tup)
#    1142 # no multi-index, so validate all of the indexers
#    1143 tup = self._validate_tuple_indexer(tup)
#
# ...

# %%
#Ejercicio 5

# %%
a
# Out:
#                                                   Name              Author  \
# 0                        10-Day Green Smoothie Cleanse            JJ Smith
# 1                                    11/22/63: A Novel        Stephen King
# 2              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 3                                                 1984       George Orwell
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 645       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 646  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 647  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 648  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 649  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#      User Rating  Reviews   Price  Price_r  Year        Genre
# ...

# %%
a.describe()
# Out:
#        User Rating        Reviews     Price_r         Year
# count   650.000000     650.000000  650.000000   650.000000
# mean      4.635385   17204.853846   12.796923  2015.000000
# std       0.221517   20715.650579   10.168624     3.744539
# min       3.300000      37.000000    0.000000  2009.000000
# 25%       4.500000    4789.250000    7.000000  2012.000000
# 50%       4.700000    9957.000000   11.000000  2015.000000
# 75%       4.800000   22359.250000   15.000000  2018.000000
# max       4.900000  193482.000000  105.000000  2021.000000

# %%
ftemp = a.loc[ : , ['Year','Name','Author','User Rating']]

# %%
ftemp
# Out:
#      Year                                               Name  \
# 0    2016                      10-Day Green Smoothie Cleanse
# 1    2011                                  11/22/63: A Novel
# 2    2018            12 Rules for Life: An Antidote to Chaos
# 3    2021                                               1984
# 4    2017                             1984 (Signet Classics)
# ..    ...                                                ...
# 645  2019       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 646  2016  You Are a Badass: How to Stop Doubting Your Gr...
# 647  2017  You Are a Badass: How to Stop Doubting Your Gr...
# 648  2018  You Are a Badass: How to Stop Doubting Your Gr...
# 649  2019  You Are a Badass: How to Stop Doubting Your Gr...
#
#                  Author  User Rating
# 0              JJ Smith          4.7
# 1          Stephen King          4.6
# 2    Jordan B. Peterson          4.7
# 3         George Orwell          4.7
# 4         George Orwell          4.7
# ...

# %%
ftemp.describe()
# Out:
#               Year  User Rating
# count   650.000000   650.000000
# mean   2015.000000     4.635385
# std       3.744539     0.221517
# min    2009.000000     3.300000
# 25%    2012.000000     4.500000
# 50%    2015.000000     4.700000
# 75%    2018.000000     4.800000
# max    2021.000000     4.900000
